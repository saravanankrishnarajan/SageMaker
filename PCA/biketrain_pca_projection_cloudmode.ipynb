# %%
import sys
import numpy as np
import pandas as pd
import math
import os

# %% [markdown]
# ### PCA Cloud prediction
#
# #### Invoke sagemaker prediction service

# %%
import boto3
import re
from sagemaker import get_execution_role
import sagemaker

# SDK 2 serializer and deserializers
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
# SDK 2.0
endpoint_name = 'pca-biketrain-v1'
predictor = sagemaker.predictor.Predictor(endpoint_name=endpoint_name)

# %%
predictor.serializer=CSVSerializer()
predictor.deserializer=JSONDeserializer()

# %%
# We are not going to use numeric features: 'temp','atemp','humidity','windspeed'
# Instead, we are going to use new components (aka features) generated by PCA for model training and testing
columns = ['count', 'season', 'holiday', 'workingday', 'weather','year', 'month', 'day', 'dayofweek','hour']

# PCA Training
columns_for_pca = ['temp','atemp','humidity','windspeed']

# %%
df = pd.read_csv('train_normalized.csv')
df_test = pd.read_csv('test_normalized.csv')

# %%
df.head(2)
# Out:
#       count  season  holiday  workingday  weather      temp     atemp  \
# 0  2.833213       1        0           0        1  0.118761  0.173736
# 1  3.713572       1        0           0        1  0.110467  0.166986
#
#    humidity  windspeed  year  month  day  dayofweek  hour
# 0  0.977605        0.0  2011      1    1          5     0
# 1  0.979751        0.0  2011      1    1          5     1

# %%
df_test.head(2)
# Out:
#               datetime  season  holiday  workingday  weather      temp  \
# 0  2011-01-20 00:00:00       1        0           1        1  0.167404
# 1  2011-01-20 01:00:00       1        0           1        1  0.181869
#
#       atemp  humidity  windspeed  year  month  day  dayofweek  hour
# 0  0.178475  0.879419   0.408344  2011      1   20          3     0
# 1  0.232625  0.955410   0.000000  2011      1   20          3     1

# %%
df[colums_for_pca].head(2)
# Out:
#        temp     atemp  humidity  windspeed
# 0  0.118761  0.173736  0.977605        0.0
# 1  0.110467  0.166986  0.979751        0.0

# %%
df[columns_for_pca].head().values
# Out:
# array([[0.11876091, 0.17373611, 0.97760504, 0.        ],
#        [0.11046696, 0.16698636, 0.9797513 , 0.        ],
#        [0.11046696, 0.16698636, 0.9797513 , 0.        ],
#        [0.12779176, 0.1869474 , 0.97402255, 0.        ],
#        [0.12779176, 0.1869474 , 0.97402255, 0.        ]])

# %%
test = df[columns_for_pca].head().values

# %%
type(test)
# Out:
# numpy.ndarray

# %%
result = predictor.predict(test)

# %%
result
# Out:
# {'projections': [{'projection': [-0.3131008744239807, -0.9453434944152832]},
#   {'projection': [-0.32269516587257385, -0.9424567222595215]},
#   {'projection': [-0.32269516587257385, -0.9424567222595215]},
#   {'projection': [-0.2985489070415497, -0.9494175910949707]},
#   {'projection': [-0.2985489070415497, -0.9494175910949707]}]}

# %%
l = [values['projection'] for values in result['projections']]

# %%
l
# Out:
# [[-0.3131008744239807, -0.9453434944152832],
#  [-0.32269516587257385, -0.9424567222595215],
#  [-0.32269516587257385, -0.9424567222595215],
#  [-0.2985489070415497, -0.9494175910949707],
#  [-0.2985489070415497, -0.9494175910949707]]

# %%
# for a large number of predictions we can split the input data
def get_projection(arr_features):
    projections=[]
    for arr in np.array_split(arr_features,100):
        #print(arr.shape)
        result = predictor.predict(arr)
        projections +=[values['projection'] for values in result['projections']]
    return projections

# %%
def replace_features(df,columns_for_pca):
    
    arr_features = df[columns_for_pca].values
    
    projections = get_projection(arr_features)
    df_projection = pd.DataFrame(projections)
    
    tcols = []
    
    for i in range(df_projection.shape[1]):
        tcols.append('component_'+str(i))
        
    df_projection.columns = tcols
    print('components:',tcols)
    
    for col in df_projection.columns:
        df[col] = df_projection[col]
        
    df.drop(columns_for_pca,inplace=True, axis=1)
    
    return tcols

# %%
df.head(2)
# Out:
#       count  season  holiday  workingday  weather      temp     atemp  \
# 0  2.833213       1        0           0        1  0.118761  0.173736
# 1  3.713572       1        0           0        1  0.110467  0.166986
#
#    humidity  windspeed  year  month  day  dayofweek  hour
# 0  0.977605        0.0  2011      1    1          5     0
# 1  0.979751        0.0  2011      1    1          5     1

# %%
new_cols = replace_features(df,columns_for_pca)
# Out:
# components: ['component_0', 'component_1']

# %%
df.head(2)
# Out:
#       count  season  holiday  workingday  weather  year  month  day  \
# 0  2.833213       1        0           0        1  2011      1    1
# 1  3.713572       1        0           0        1  2011      1    1
#
#    dayofweek  hour  component_0  component_1
# 0          5     0    -0.313101    -0.945343
# 1          5     1    -0.322695    -0.942457

# %% [raw]
# # double check
# 0.118761	0.173736	0.977605	0.0
# -0.313101	-0.945343
#
# predictor.predict([[0.11876090844342149,0.1737361053905541,0.9776050390159696,0.0]])
# {'projections': [{'projection': [-0.3131008744239807, -0.9453434944152832]}]}

# %%
replace_features(df_test,columns_for_pca)
# Out:
# components: ['component_0', 'component_1']
# ['component_0', 'component_1']

# %%
columns
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'year',
#  'month',
#  'day',
#  'dayofweek',
#  'hour']

# %%
for col in new_cols:
    columns.append(col)

# %%
columns
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'year',
#  'month',
#  'day',
#  'dayofweek',
#  'hour',
#  'component_0',
#  'component_1']

# %%
df_test
# Out:
#                  datetime  season  holiday  workingday  weather  year  month  \
# 0     2011-01-20 00:00:00       1        0           1        1  2011      1
# 1     2011-01-20 01:00:00       1        0           1        1  2011      1
# 2     2011-01-20 02:00:00       1        0           1        1  2011      1
# 3     2011-01-20 03:00:00       1        0           1        1  2011      1
# 4     2011-01-20 04:00:00       1        0           1        1  2011      1
# ...                   ...     ...      ...         ...      ...   ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  2012     12
# 6489  2012-12-31 20:00:00       1        0           1        2  2012     12
# 6490  2012-12-31 21:00:00       1        0           1        1  2012     12
# 6491  2012-12-31 22:00:00       1        0           1        1  2012     12
# 6492  2012-12-31 23:00:00       1        0           1        1  2012     12
#
#       day  dayofweek  hour  component_0  component_1
# 0      20          3     0    -0.102386    -0.955772
# 1      20          3     1    -0.232725    -0.964794
# 2      20          3     2    -0.232725    -0.964794
# 3      20          3     3    -0.176658    -0.982781
# 4      20          3     4    -0.176658    -0.982781
# ...   ...        ...   ...          ...          ...
# 6488   31          0    19    -0.197231    -0.979067
# 6489   31          0    20    -0.197231    -0.979067
# 6490   31          0    21    -0.197231    -0.979067
# 6491   31          0    22    -0.180584    -0.983338
# 6492   31          0    23    -0.223084    -0.974663
#
# [6493 rows x 12 columns]

# %%
# Training = 70% of the data
# Validation = 30% of the data
# Randomize the datset
np.random.seed(5)
l = list(df.index)
np.random.shuffle(l)
df = df.iloc[l]

# %%
rows = df.shape[0]
train = int(rows*0.7)
test = rows-train

# %%
rows, train, test
# Out:
# (10886, 7620, 3266)

# %%
7620+3266
# Out:
# 10886

# %%
# Write Training Set
df[:train].to_csv('bike_train_pca_cloud.csv'
                          ,index=False,header=False
                          ,columns=columns)

# %%
# Write Training Set
df[train:].to_csv('bike_validation_pca_cloud.csv'
                          ,index=False,header=False
                          ,columns=columns)

# %%
# Test Data has only input features
df_test.to_csv('bike_test_pca_cloud.csv',index=False)

# %%
# Write Column List
with open('bike_train_column_list_pca_cloud.txt','w') as f:
    f.write(','.join(columns))

# %%
predictor.delete_endpoint(endpoint_name)
